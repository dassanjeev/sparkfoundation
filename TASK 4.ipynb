# %% [markdown]
# # SANJEEV DAS
# ## Terrorism DataSet from 1970 - 2017
# ---
#
# Exploring The DATA SET and finding certain trend
#
# Importing the packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\sanjeev\\Downloads\\globalterrorismdb_0718dist.csv",encoding = "latin1",low_memory=False)
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
sns.heatmap(data.isnull(),cmap="coolwarm")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
x=list(data["longitude"][20000:].values)
y=list(data["latitude"][20000:].values)
x1=list(data["longitude"][:10000].values)
y1=list(data["latitude"][:10000].values)
plt.figure(figsize=(12,6))
plt.scatter(x,y,c="red",marker=".")
plt.scatter(x1,y1,c="red",marker=".")
plt.show()

# %% [markdown]
# ## Total Terror Attact over the world from 1970 - 2017
# ### The cluster in Asian Continent and African Continent is more

# %%
plt.figure(figsize=(12,6))
sns.histplot(x="iyear",data=data,binwidth=1,color="red")
plt.show()

# %% [markdown]
# ## It can be seen that terror attact and terrorism is increasing with time
# ### 2017 has the highest number of terror attact

# %%
df = data.copy()
df=df.dropna(1)

# %%
sns.heatmap(df.isnull(),cmap="coolwarm")
plt.show()

# %%
df[df["iyear"] < 1981]["iyear"].value_counts()
# Out:
# 1980    2662
# 1979    2662
# 1978    1526
# 1977    1319
# 1976     923
# 1975     740
# 1970     651
# 1974     581
# 1972     568
# 1973     473
# 1971     471
# Name: iyear, dtype: int64

# %%
x=list(data[data["iyear"] < 1981]["longitude"][20000:].values)
y=list(data[data["iyear"] < 1981]["latitude"][20000:].values)
x1=list(data[data["iyear"] < 1981]["longitude"][:10000].values)
y1=list(data[data["iyear"] < 1981]["latitude"][:10000].values)
plt.figure(figsize=(12,6))
plt.scatter(x,y,c="red",marker=".")
plt.scatter(x1,y1,c="red",marker=".")
plt.show()

# %% [markdown]
# ## Terror attact till the year  1980
# ### It can be seen that the IRAN and near countries have a high terror from the very start

# %%
x=list(data[data["iyear"] < 1991 ]["longitude"][20000:].values)
y=list(data[data["iyear"] < 1991]["latitude"][20000:].values)
x1=list(data[data["iyear"] < 1991]["longitude"][:10000].values)
y1=list(data[data["iyear"] < 1991]["latitude"][:10000].values)
plt.figure(figsize=(12,6))
plt.scatter(x,y,c="red",marker=".")
plt.scatter(x1,y1,c="red",marker=".")
plt.show()

# %% [markdown]
# ## Terror till the year 1990
# ### In these years it can be seen terror attact in INDIA has increased and also in south AFRICA
# ### Attact on the Costal Lines can be seen more prominently in USA

# %%
x=list(data[data["iyear"] < 2001 ]["longitude"][20000:].values)
y=list(data[data["iyear"] < 2001]["latitude"][20000:].values)
x1=list(data[data["iyear"] < 2001]["longitude"][:10000].values)
y1=list(data[data["iyear"] < 2001]["latitude"][:10000].values)
plt.figure(figsize=(12,6))
plt.scatter(x,y,c="red",marker=".")
plt.scatter(x1,y1,c="red",marker=".")
plt.show()

# %% [markdown]
# ## Terror Attact till 2000
# ## ISLAMIC Country has a high terrorism rate
# # They are the one affected the most because of terror attact

# %%
#data[data["gname"]=="Taliban"]
#Islamic State of Iraq and the Levant (ISIL)
#Shining Path (SL)
#Al-Shabaab
#New People's Army (NPA)
#Irish Republican Army (IRA)
#Revolutionary Armed Forces of Colombia (FARC)
#Boko Haram
plt.figure(figsize=(12,6))

x=list(data[data["gname"]=="Unknown"]["longitude"][20000:].values)+list(data[data["gname"]=="Unknown"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Unknown"]["latitude"][20000:].values)+list(data[data["gname"]=="Unknown"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Unkown")

x=list(data[data["gname"]=="Boko Haram"]["longitude"][20000:].values)+list(data[data["gname"]=="Boko Haram"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Boko Haram"]["latitude"][20000:].values)+list(data[data["gname"]=="Boko Haram"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Boko Haram")


x=list(data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"]["longitude"][20000:].values)+list(data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"]["latitude"][20000:].values)+list(data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Revolutionary Armed Forces of Colombia (FARC)")

x=list(data[data["gname"]=="Irish Republican Army (IRA)"]["longitude"][20000:].values)+list(data[data["gname"]=="Irish Republican Army (IRA)"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Irish Republican Army (IRA)"]["latitude"][20000:].values)+list(data[data["gname"]=="Irish Republican Army (IRA)"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Irish Republican Army (IRA)")

x=list(data[data["gname"]=="New People's Army (NPA)"]["longitude"][20000:].values)+list(data[data["gname"]=="New People's Army (NPA)"]["longitude"][:10000].values)
y=list(data[data["gname"]=="New People's Army (NPA)"]["latitude"][20000:].values)+list(data[data["gname"]=="New People's Army (NPA)"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="New People's Army (NPA)")


x=list(data[data["gname"]=="Al-Shabaab"]["longitude"][20000:].values)+list(data[data["gname"]=="Al-Shabaab"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Al-Shabaab"]["latitude"][20000:].values)+list(data[data["gname"]=="Al-Shabaab"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Al-Shabaab")

x=list(data[data["gname"]=="Taliban"]["longitude"][20000:].values)+list(data[data["gname"]=="Taliban"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Taliban"]["latitude"][20000:].values)+list(data[data["gname"]=="Taliban"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Taliban")

x=list(data[data["gname"]=="Islamic State of Iraq and the Levant (ISIL)"]["longitude"][20000:].values)+list(data[data["gname"]=="Islamic State of Iraq and the Levant (ISIL)"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Islamic State of Iraq and the Levant (ISIL)"]["latitude"][20000:].values)+list(data[data["gname"]=="Islamic State of Iraq and the Levant (ISIL)"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Islamic State of Iraq and the Levant (ISIL)")

x=list(data[data["gname"]=="Shining Path (SL)"]["longitude"][20000:].values)+list(data[data["gname"]=="Shining Path (SL)"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Shining Path (SL)"]["latitude"][20000:].values)+list(data[data["gname"]=="Shining Path (SL)"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Shining Path (SL)")

x=list(data[data["gname"]=="Farabundo Marti National Liberation Front (FMLN)"]["longitude"][20000:].values)+list(data[data["gname"]=="Farabundo Marti National Liberation Front (FMLN)"]["longitude"][:10000].values)
y=list(data[data["gname"]=="Farabundo Marti National Liberation Front (FMLN)"]["latitude"][20000:].values)+list(data[data["gname"]=="Farabundo Marti National Liberation Front (FMLN)"]["latitude"][:10000].values)
plt.scatter(x,y,marker=".",label="Farabundo Marti National Liberation Front (FMLN)")
plt.legend(bbox_to_anchor=(0.9, 0.9))
plt.show()

# %%
data["gname"].value_counts()[:10]
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: gname, dtype: int64

# %% [markdown]
# ## Most of the Attact were from Unknown souces'
# ### Also TALIBAN is the TERRORIST GROUP which attacted the most

# %% [markdown]
# ---
# ### Trying to find if there is a trend in the Months or Days The Attack has happened

# %%
x=dict(data["imonth"].value_counts())
plt.figure(figsize=(12,4))
plt.bar(x.keys(),x.values())
plt.show()

# %%
x=dict(data["iday"].value_counts())
plt.figure(figsize=(12,4))
plt.bar(x.keys(),x.values())
plt.show()

# %% [markdown]
# ## It can be seen there is no trend in Attacks with respect to specific Day or Month
# ### All the Attacks are random and without any special intend of particular day or date

# %%
x=dict(data[data["gname"]=="Taliban"]["imonth"].value_counts())
plt.figure(figsize=(12,4))
plt.bar(x.keys(),x.values())
plt.show()

# %% [markdown]
# ## A intresting trend can be seen while studying the Attacks of TALIBAN
# ### Maximum number of Attact are in MAY, JUNE , JULY , AUG, SEP
# ### While the Start and the ending month have a less number of Attack

# %% [markdown]
# ---
# After finding a trend in TALIBAN trying to Check in other Group also

# %%
x=dict(data[data["gname"]=="Islamic State of Iraq and the Levant (ISIL)"]["imonth"].value_counts())
plt.figure(figsize=(12,4))
plt.bar(x.keys(),x.values())
plt.show()

# %% [markdown]
# ### There is no trend in Islamic State of Iraq and the Levant (ISIL) for attack in specific time of the year

# %%
#Revolutionary Armed Forces of Colombia (FARC)
plt.figure(figsize=(12,6))
sns.histplot(x="iyear",data=data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"],binwidth=1,color="red")
plt.show()
x=dict(data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"]["imonth"].value_counts())
plt.figure(figsize=(12,4))
plt.bar(x.keys(),x.values())
plt.show()
x=dict(data[data["gname"]=="Revolutionary Armed Forces of Colombia (FARC)"]["iday"].value_counts())
plt.figure(figsize=(12,4))
plt.bar(x.keys(),x.values())
plt.show()

# %% [markdown]
# ## A lot of Random Attack arfe done by Revolutionary Armed Forces of Colombia (FARC)

# %%
suicide={}
for i in dict(data["gname"].value_counts()[1:12]).keys():
    suicide[i]=sum(data[data["gname"]==i]["suicide"])

# %%
plt.bar(suicide.keys(),suicide.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Group which has most number of Human bomb

# %%
df["dbsource"].value_counts()
# Out:
# START Primary Collection                    78002
# PGIS                                        63740
# ISVG                                        17207
# CETIS                                       16163
# CAIN                                         1588
# UMD Schmid 2012                              1165
# Hewitt Project                               1005
# UMD Algeria 2010-2012                         848
# UMD South Africa                              449
# UMD Sri Lanka 2011                            405
# UMD Miscellaneous                             259
# Anti-Abortion Project 2010                    186
# Eco Project 2010                              147
# UMD JTMM Nepal 2012                           104
# HSI                                            97
# Hyland                                         71
# Hijacking DB                                   54
# UMD Encyclopedia of World Terrorism 2012       48
# CBRN Global Chronology                         46
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'vicinity', 'crit1', 'crit2',
#        'crit3', 'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'targtype1', 'targtype1_txt', 'gname', 'individual', 'weaptype1',
#        'weaptype1_txt', 'property', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
df["country_txt"].value_counts()
# The country which has suffered the most attacks
# Out:
# Iraq                 24636
# Pakistan             14368
# Afghanistan          12731
# India                11960
# Colombia              8306
#                      ...
# Falkland Islands         1
# International            1
# Wallis and Futuna        1
# Vatican City             1
# Andorra                  1
# Name: country_txt, Length: 205, dtype: int64

# %% [markdown]
# ## It can be seen that terror attact and terrorism is increasing with time
# ### 2017 has the highest number of terror attact
# ### In these years it can be seen terror attact in INDIA has increased and also in south AFRICA
# ### Attact on the Costal Lines can be seen more prominently in USA
# ## Most of the Attact were from Unknown souces'
# ### Also TALIBAN is the TERRORIST GROUP which attacted the most
# ## A intresting trend can be seen while studying the Attacks of TALIBAN
# ### Maximum number of Attact are in MAY, JUNE , JULY , AUG, SEP
# ### While the Start and the ending month have a less number of Attack
